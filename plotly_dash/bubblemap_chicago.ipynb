# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('./chicago-crimes-2016-2018.csv')

# %%
df = df.loc[df['Year'].isin([2017])]
df = df.loc[df['Category'].isin(['ASSAULT'])]

# %%
df.sort_values('Month', inplace=True)

# %%
df
# Out:
#         Unnamed: 0 Category                 Date  Year   Latitude  Longitude  \
# 560027     3039626  ASSAULT  2017-01-20 17:15:00  2017  41.712678 -87.602509
# 127727      723631  ASSAULT  2017-01-27 12:45:00  2017  42.005945 -87.704579
# 699191     3864484  ASSAULT  2017-01-04 17:00:00  2017  41.751271 -87.605938
# 699226     3864737  ASSAULT  2017-01-23 00:08:00  2017  41.751271 -87.605938
# 46782       256956  ASSAULT  2017-01-16 03:30:00  2017  41.774062 -87.596057
# ...            ...      ...                  ...   ...        ...        ...
# 24088       132886  ASSAULT  2017-12-06 01:30:00  2017  41.809297 -87.591967
# 486919     2621818  ASSAULT  2017-12-10 13:50:00  2017  41.748847 -87.600267
# 742144     4100568  ASSAULT  2017-12-17 22:46:00  2017  41.746871 -87.652820
# 568981     3092244  ASSAULT  2017-12-01 10:35:00  2017  41.718734 -87.534077
# 78049       437330  ASSAULT  2017-12-01 14:50:00  2017  41.968394 -87.714141
#
#         Month  Day  Time  DayOfWeek  \
# ...

# %%
fig = px.scatter_geo(df, lat='Latitude', lon='Longitude', animation_frame="Month", color_discrete_sequence=["darkblue"])
fig.update_layout(mapbox_style="open-street-map")
fig.update_geos(fitbounds="locations")

fig.show()
# Out:
# <div>                            <div id="12d904f9-abc6-4ef1-9efc-40e37d75e16e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12d904f9-abc6-4ef1-9efc-40e37d75e16e")) {                    Plotly.newPlot(                        "12d904f9-abc6-4ef1-9efc-40e37d75e16e",                        [{"geo":"geo","hovertemplate":"Month=1<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[41.712677534,42.005945401,41.751270583,41.751270583,41.7740621,42.005255827,41.75216896,41.666378887,41.666412783,41.666024801,41.870550571,41.754120813,41.679727112,41.752421241,41.752525969,41.870526553,42.013201177,41.754147277,41.992218187,41.802444779,41.75578311,41.754251833,41.867428687,41.762719954,41.886461703,41.881893071,41.998281878,41.760865388,41.8729
# ...
